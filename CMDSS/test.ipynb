# %%
pip install pymongo
# Out:
# ...
#    ---------------------------------------- 0.0/959.2 kB ? eta -:--:--
#    --------------------------------------- 959.2/959.2 kB 10.2 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
# ...

# %%
import pymongo
print(pymongo.__version__)
# Out:
# 4.16.0

# %%
from pymongo import MongoClient

client = MongoClient("mongodb+srv://user1:user1@cluster0.jcfbgsu.mongodb.net/?appName=Cluster0")
db = client["canteen_db"]

print(db.list_collection_names())
# Out:
# ---------------------------------------------------------------------------
# InvalidURI                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 from pymongo import MongoClient
# ----> 3 client = MongoClient("mongodb+srv://user1:user@1@cluster0.jcfbgsu.mongodb.net/?appName=Cluster0")
#       4 db = client["canteen_db"]
#       6 print(db.list_collection_names())
#
# File c:\Users\HARSHAVARDHAN\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:804, in MongoClient.__init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     799 for entity in self._host:
#     800     # A hostname can only include a-z, 0-9, '-' and '.'. If we find a '/'
#     801     # it must be a URI,
#     802     # https://en.wikipedia.org/wiki/Hostname#Restrictions_on_valid_host_names
#     803     if "/" in entity:
# --> 804         res = _validate_uri(
#     805             entity,
#     806             port,
# ...
